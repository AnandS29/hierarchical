# %%
import sys

import hydra
import logging
import itertools

import torch
import numpy as np

from plot import *
from mbrl_resources import obs2q
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-19d1c9ab9e69> in <module>
#       9
#      10 from plot import *
# ---> 11 from mbrl_resources import obs2q
#
# ~/Desktop/hybrid-workspace/hierarchical/mbrl_resources.py in <module>
#      13 from envs import *
#      14
# ---> 15 from sklearn.preprocessing import StandardScaler
#      16 from sklearn.preprocessing import MinMaxScaler
#      17
#
# ~/miniconda3/envs/continuouspred/lib/python3.6/site-packages/sklearn/__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~/miniconda3/envs/continuouspred/lib/python3.6/site-packages/sklearn/base.py in <module>
#      18
#      19 from . import __version__
# ...
